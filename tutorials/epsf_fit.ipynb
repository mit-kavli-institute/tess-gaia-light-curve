# %% [markdown]
# # ePSF Fitting
#
# This version of TGLC includes generic functions that can be used to fit an ePSF to an image with known star positions and brightnesses. This tutorial simulates an FFI cutout, walks through fitting an ePSF for the cutout, and then uses the fitted ePSF to extract aperture photometry for a target star.
#
# To install the notebook dependencies, run the following in your python environment (a virtual environment is a good idea!):
#
# ```shell
# pip install astropy matplotlib numpy jupyter photutils "tglc @ git+ssh://github.com/mit-kavli-institute/tess-gaia-light-curve"
# ```

# %%
import astropy.units as u
from astropy.visualization import simple_norm
import matplotlib.pyplot as plt
import numpy as np
from photutils.datasets import make_model_image, make_model_params, make_noise_image
from photutils.psf import CircularGaussianPSF

from tglc.aperture_photometry import get_aperture_photometry, normalize_photometry
from tglc.epsf import EPSF, fit_epsf, get_default_epsf_flux_mask, make_tglc_design_matrix
from tglc.light_curve import (
    evaluate_epsf_model,
    get_cutout_window,
    get_design_matrix_rows_for_window,
    get_psf_portion,
    make_field_design_matrix,
    make_target_design_matrix,
)
from tglc.utils.constants import convert_tess_magnitude_to_tess_flux

# %% [markdown]
# ## Create simulated image
#
# First we create a simulated 150x150 image, like the cutouts TGLC uses from actual TESS FFIs. We use a circular Gaussian PSF with FWHM 1.5 and 1000 sources with Tmag <= 13, in an exponential distribution favoring dim stars.

# %%
seed = 3141592

# %%
model = CircularGaussianPSF()
shape = (150, 150)
n_sources = 1000
params = make_model_params(
    shape,
    n_sources,
    x_name="x_0",
    y_name="y_0",
    fwhm=(1.5, 1.5),
    seed=seed,
)
# Update flux values to reflect true Tmag distribution
rng = np.random.default_rng(seed)
tmag = 13 - rng.exponential(0.75, n_sources)
params["flux"] = convert_tess_magnitude_to_tess_flux(tmag).value

# %%
plt.xscale("log")
plt.hist(params["flux"], bins=200)
plt.xlabel("Flux")
plt.ylabel("Number of sources")
plt.title("Flux Distribution (log scale)")

# %%
model_shape = (11, 11)
simulated_cutout = make_model_image(
    shape, model, params, model_shape=model_shape, x_name="x_0", y_name="y_0"
)

noise = make_noise_image(shape, distribution="gaussian", mean=5, stddev=2, seed=seed)
simulated_cutout += noise

# %%
fig, ax = plt.subplots(figsize=(6, 6))
norm = simple_norm(simulated_cutout, "sqrt", percent=99)
ax.imshow(simulated_cutout, norm=norm, origin="lower")
ax.scatter(params["x_0"], params["y_0"], s=1, marker=".", color="red")
ax.set(xlim=(0, shape[1]), ylim=(0, shape[0]))
ax.set_title("Simulated image")

# %% [markdown]
# ## Fitting an ePSF
#
# Now, we fit an ePSF for the simulated cutout using TGLC's linear methods. We can choose a shape `(sy, sx)` of the PSF model in pixel coordinates, and an oversampling factor `f`. Then evaluating the PSF amounts to linearly interpolating a grid with shape `(sy * f + 1, sx * f + 1)`. There are also 6 parameters used to describe the background: 3 for a linear gradient background and 3 for a spatially-varying contribution from TESS's CCD "straps." We will ignore the background strap contributions for now, but TGLC's package data does include FITS files with the strap data for each CCD.
#
# To run the ePSF fit, we flatten the `(sy * f + 1, sx * f + 1)` PSF grid into a column vector of parameters, plus the 6 background parameters. We also flatten the cutout into a column vector as our observed data. We then create a design matrix `M` where `M[r, c]` gives the contribution of model parameter `r` to observed data `c`. So, if `p` is our column vector of model parameters and `o` is our column vector of observed data, we are running a least squares fit for the equation `Mp =~ o`.
#
# For proper regularization, the design matrix for running fits has additional data compared to the design matrix described above. This extra data is added when `edge_compression_scale_factor` is specified in `make_tglc_design_matrix`; when it is omitted, the design matrix produced is as described above. Note that `make_tglc_design_matrix` can also make a design matrix that omits the background parameters, which happens if `background_strap_mask` is not specified - this is why we set `background_strap_mask` to all zeros in the code below rather than omitting it.
#
# `fit_epsf` also does not fit every pixel: by default it excludes the pixels flagged in the base mask (e.g. saturated pixels) plus pixels dimmer than 0.8 times the median flux, discarding roughly the sky-dominated portion of the image. That default mask is exposed as `get_default_epsf_flux_mask`, so we can visualize exactly which pixels participate in the fit — and a custom mask can be passed to `fit_epsf` via its `flux_mask` parameter to experiment with different pixel selections.

# %%
flux_mask = get_default_epsf_flux_mask(simulated_cutout, np.zeros(shape, dtype=bool))
plt.imshow(flux_mask, origin="lower")
plt.title("Pixels excluded from the fit (default mask)")

# %%
star_positions = np.column_stack([params["x_0"].data, params["y_0"].data])
flux_ratios = params["flux"] / max(params["flux"])
psf_size = 11
oversample_factor = 2

# Note: the make_tglc_design_matrix function is just-in-time (JIT) compiled, so it will be slow on
# the first time it is called but much faster after that
fit_design_matrix, regularization_dimensions = make_tglc_design_matrix(
    shape,
    (psf_size, psf_size),
    oversample_factor,
    star_positions,
    flux_ratios,
    background_strap_mask=np.zeros(shape),  # no contribution from CCD straps
    edge_compression_scale_factor=1e-4,
)
epsf_parameters = fit_epsf(
    fit_design_matrix, simulated_cutout, np.zeros(shape, dtype=bool), 1.4, regularization_dimensions
)

# %% [markdown]
# ## Wrapping the parameters in `EPSF`
#
# The fitted parameters are a flat vector: the oversampled PSF grid values followed by the 6 background parameters. The `EPSF` class bundles this array together with the configuration it was fit with (`psf_size`, `oversample`) and provides named views — `psf_parameters`, `background_parameters`, `oversampled_psf_shape`, `background_parameter(name)` — instead of hardcoded slicing like `epsf[:-6]`. The constructor also validates the array length against the configuration, so a mismatched `psf_size`/`oversample` fails immediately instead of producing silently wrong slices.
#
# In the pipeline the TESS identifiers (orbit, sector, camera, CCD, cutout indices) tie a fitted ePSF back to its originating FFI cutout; for a simulated image we use placeholders.

# %%
epsf = EPSF(
    epsf_parameters[np.newaxis, :],  # EPSF holds per-cadence rows; we fit a single cadence
    psf_size=psf_size,
    oversample=oversample_factor,
    orbit=0,
    sector=0,
    camera=1,
    ccd=1,
    cutout_x=-1,
    cutout_y=-1,
)
epsf

# %%
plt.imshow(
    epsf.psf_parameters[0].reshape(epsf.oversampled_psf_shape),
    extent=(-11.5, 11.5, -11.5, 11.5),
    origin="lower",
)
plt.scatter(0, 0, marker=".", color="red")
plt.title("ePSF")

# %%
# The forward-modeling design matrix comes from the EPSF itself, which fills in the PSF shape
# and oversampling it was fit with (and omits the fitting-only edge-compression rows).
forward_model_design_matrix, _ = epsf.make_design_matrix(
    shape, star_positions, flux_ratios, np.zeros(shape)
)
model_data = evaluate_epsf_model(forward_model_design_matrix, epsf.array, shape)[0]

# %%
norm = simple_norm(np.stack([simulated_cutout, model_data]), "sqrt", percent=99)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.imshow(simulated_cutout, norm=norm, origin="lower")
ax1.scatter(params["x_0"], params["y_0"], s=1, marker=".", color="red")
ax1.set(xlim=(-0.5, shape[1] - 0.5), ylim=(-0.5, shape[0] - 0.5))
ax1.set_title("Simulated image")

ax2.imshow(model_data, norm=norm, origin="lower")
ax2.scatter(params["x_0"], params["y_0"], s=1, marker=".", color="red")
ax2.set(xlim=(-0.5, shape[1] - 0.5), ylim=(-0.5, shape[0] - 0.5))
ax2.set_title("Image with ePSF model")

# %% [markdown]
# ## Decontaminating a target's cutout
#
# To measure one star, TGLC crops a small window around it and subtracts a forward model of everything else. The steps are individually callable: `get_cutout_window` picks the (edge-clamped) window, `get_design_matrix_rows_for_window` selects the matching rows of the full design matrix, `make_target_design_matrix` models the target alone, and `make_field_design_matrix` subtracts the target from the full model — so evaluating it with the complete parameter array models the field stars *and* the background. Subtracting that from the raw cutout leaves (ideally) only the target.
#
# The target's PSF model also gives `get_psf_portion`, the fraction of the star's flux landing in each cutout pixel, which the photometric normalization below uses to predict how much catalog flux should fall in the aperture.

# %%
# Target: the brightest star that isn't too close to the image edge
interior = (
    (params["x_0"] > 5)
    & (params["x_0"] < shape[1] - 5)
    & (params["y_0"] > 5)
    & (params["y_0"] < shape[0] - 5)
)
target = np.flatnonzero(interior)[np.argmax(params["flux"][interior])]
target_x, target_y = params["x_0"][target], params["y_0"][target]

window = get_cutout_window(target_x, target_y, shape, cutout_size=5)
target_x_in_cutout = target_x - window.left
target_y_in_cutout = target_y - window.bottom
# The photometry functions take a (time, height, width) stack; our simulation is one cadence
raw_cutout = simulated_cutout[np.newaxis, window.bottom : window.top, window.left : window.right]

target_design_matrix = make_target_design_matrix(
    epsf, window.shape, target_x_in_cutout, target_y_in_cutout, flux_ratios[target]
)
field_design_matrix = make_field_design_matrix(
    forward_model_design_matrix[get_design_matrix_rows_for_window(window, shape[1])],
    target_design_matrix,
)
# The field model includes the background model, so this subtraction removes both
decontaminated_cutout = raw_cutout - evaluate_epsf_model(
    field_design_matrix, epsf.array, window.shape
)

target_psf_model = evaluate_epsf_model(target_design_matrix, epsf.psf_parameters, window.shape)
psf_portions = get_psf_portion(target_psf_model)

# %%
norm = simple_norm(raw_cutout[0], "sqrt", percent=99)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.imshow(raw_cutout[0], norm=norm, origin="lower")
ax1.scatter(target_x_in_cutout, target_y_in_cutout, marker=".", color="red")
ax1.set_title("Raw cutout")

ax2.imshow(decontaminated_cutout[0], norm=norm, origin="lower")
ax2.scatter(target_x_in_cutout, target_y_in_cutout, marker=".", color="red")
ax2.set_title("Decontaminated cutout")

# %% [markdown]
# ## Aperture photometry: measurement, then normalization
#
# Photometry happens in two independently-callable phases. `get_aperture_photometry` is pure measurement: it sums the flux in a square aperture, computes flux-weighted centroids, and NaN-masks saturated cadences, returning a table with `raw_flux` and centroid columns (the aperture window it derived rides along in the table metadata). No normalization is applied, so `raw_flux` is the quantity to use when absolute levels matter.
#
# `normalize_photometry` then adds the normalized products on top: it shifts the raw flux by a single additive scalar (the "local background") so the good-cadence median lands on the flux expected in the aperture for the target's TESS magnitude, and converts to magnitudes. The shift is recorded in the metadata, so `flux = raw_flux - local_background` and the normalization is fully invertible. By default it returns an augmented copy; `inplace=True` mutates the supplied table instead.
#
# Our simulated fluxes are the per-second catalog values used directly as image counts, so the effective exposure time is 1 second.

# %%
exposure_time = 1 * u.second

photometry = get_aperture_photometry(
    decontaminated_cutout,
    3,
    round(target_x_in_cutout),
    round(target_y_in_cutout),
    exposure_time,
)
print(f"aperture window: {photometry.meta['aperture_limits']}")
photometry

# %%
normalized = normalize_photometry(
    photometry,
    np.zeros(1, dtype=int),  # quality flags: the single simulated cadence is good
    tmag[target],
    exposure_time,
    psf_portions,
)
# With a single cadence the good-cadence median IS the one measurement, so the normalized
# flux lands on the catalog expectation by construction. The informative quantity here is
# local_background: how far the raw measurement sat from the catalog-expected aperture flux.
print(f"raw aperture flux:     {normalized['raw_flux'][0]:.1f}")
print(f"local background:      {normalized.meta['local_background']:.1f}")
print(f"normalized magnitude:  {normalized['magnitude'][0]:.4f} (target Tmag {tmag[target]:.4f})")
normalized
